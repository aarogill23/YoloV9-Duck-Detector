# %%
from ultralytics import YOLO
model = YOLO("/Users/aaron/Library/CloudStorage/OneDrive-SamfordUniversity/Fall 2024/COSC 490/YoloV9-Duck-Detector/runs/detect/train19/weights/best.pt")
results = model()

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

model = YOLO('runs/detect/train19/weights/best.pt')
resultSelf = model('me.jpeg')
resultOther = model('prof.png')
resultDuck = model('Anas_platyrhynchos_male_female_quadrat.jpg')
plt.imshow(resultSelf[0].plot())
plt.title("Yolo results")
plt.show()
plt.imshow(resultOther[0].plot())
plt.title("Yolo results")
plt.show()
plt.imshow(resultDuck[0].plot())
plt.title("Yolo results")
plt.show()
# Out:
# image 1/1 /Users/aaron/Library/CloudStorage/OneDrive-SamfordUniversity/Fall 2024/COSC 490/YoloV9-Duck-Detector/me.jpeg: 640x320 1 Duck, 127.2ms
# Speed: 3.5ms preprocess, 127.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 320)
#
# image 1/1 /Users/aaron/Library/CloudStorage/OneDrive-SamfordUniversity/Fall 2024/COSC 490/YoloV9-Duck-Detector/prof.png: 640x448 (no detections), 147.3ms
# Speed: 2.2ms preprocess, 147.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /Users/aaron/Library/CloudStorage/OneDrive-SamfordUniversity/Fall 2024/COSC 490/YoloV9-Duck-Detector/Anas_platyrhynchos_male_female_quadrat.jpg: 640x640 1 Duck, 209.5ms
# Speed: 4.7ms preprocess, 209.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
